# %% [markdown]
# # Subtask Detection
#
# Here we us the models learned by IDyOM to detect information theoretic boundaries which separate the subtasks 'pickup key' and 'unlock door'.

# %%
import numpy as np
import pandas
import matplotlib.pyplot as plt
import os
import sys
sys.path.insert(0, os.path.abspath('./'))
import gridworld as gw

# %% [markdown]
# We consider 5 different models. Each model is described in the corresponging notebook e.g. "idyom-action-action.ipynb".

# %%
model_names = ['idyom-action-action',
                'idyom-select-maxlinks2',
                "idyom-select-maxlinks2-plus",
                "idyom-select-maxlinks3",
                "idyom-select-maxlinks3-minus",
                "idyom-select-maxlinks3-plus"]
models = [gw.load_data(l+".csv") for l in model_names]

# %% [markdown]
# The boundary estimators use information content, information gain and entropy to detect where a subtask boundary might be.

# %%
estimator_names = ["min_ic",
                   "min_h",
                   "max_h_diff",
                   "max_h_diff_minus1",
                   "max_ic_diff",
                   "max_ic_diff_minus1",
                   "max_ig_diff",
                   "max_ig_diff_minus1",
                   "max_h_ic",
                   "max_ig_ic"]
estimators = [gw.min_ic,
              gw.min_h,
              gw.max_h_diff,
              gw.max_h_diff_minus1,
              gw.max_ic_diff,
              gw.max_ic_diff_minus1,
              gw.max_ig_diff,
              gw.max_ig_diff_minus1,
              gw.max_h_ic,
              gw.max_ig_ic]

# %% [markdown]
# The following table contains numbers of correct subtask boundaries detected (out of 1000) for each model (columns) and estimator (rows).

# %%
results = {}

for m,M in enumerate(model_names):
    results[M] = [gw.eval_model(models[m],e) for e in estimators]
    
pandas.DataFrame(data=results,index=estimator_names)
# Out:
#                     idyom-action-action  idyom-select-maxlinks2  \
# min_ic                                0                     673
# min_h                                62                     670
# max_h_diff                           32                      20
# max_h_diff_minus1                   253                     683
# max_ic_diff                         209                      15
# max_ic_diff_minus1                    6                     225
# max_ig_diff                          57                     649
# max_ig_diff_minus1                  225                      59
# max_h_ic                              0                     661
# max_ig_ic                             7                     751
#
#                     idyom-select-maxlinks2-plus  idyom-select-maxlinks3  \
# min_ic                                      665                     622
# min_h                                       672                     617
# max_h_diff                                   19                       1
# max_h_diff_minus1                           698                     680
# max_ic_diff                                  18                       1
# max_ic_diff_minus1                          229                     241
# max_ig_diff                                 671                     634
# max_ig_diff_minus1                           68                      27
# max_h_ic                                    660                     637
# max_ig_ic                                   753                     683
#
#                     idyom-select-maxlinks3-minus  idyom-select-maxlinks3-plus
# min_ic                                       625                          624
# min_h                                        612                          621
# max_h_diff                                     4                            1
# max_h_diff_minus1                            662                          687
# max_ic_diff                                    4                            2
# max_ic_diff_minus1                           226                          243
# max_ig_diff                                  676                          620
# max_ig_diff_minus1                            31                           29
# max_h_ic                                     645                          618
# max_ig_ic                                    693                          685
